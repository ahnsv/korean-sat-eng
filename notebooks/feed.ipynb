# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
from elasticsearch_dsl import connections
from elasticsearch import Elasticsearch


def create_es_connection() -> Elasticsearch:
    """ElasticSearch Connection을 만듭니다.

    Raises:
        e: [description]

    Returns:
        ElasticSearch: [ElasticSearch Connection]
    """
    try:
        conn = connections.create_connection(
            alias="connection", hosts=["localhost:9200"], timeout=60
        )
        return conn
    except Exception as e:
        raise e

# %%
conn = create_es_connection()

# %%
from datetime import datetime
from elasticsearch_dsl import Document, Text, Float, Date, Keyword

class Vocabulary(Document):
    name = Text()
    meaning = Text()
    tags = Keyword()
    score: Float()
    created_at: Date() = datetime.now()
    updated_at: Date() = datetime.now()

    class Index:
        name = "vocabularies"
    
    def save(self, **kwargs):
        # TODO: check vocab existence
        return super().save(**kwargs)

# %%
Vocabulary.init()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /usr/local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /usr/local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     250
# --> 251             response = self.pool.urlopen(
#     252                 method, url, body, retries=Retry(False), headers=request_headers, **kw
#
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     506             # Disabled, indicate to re-raise the error.
# --> 507             raise six.reraise(type(error), error, _stacktrace)
#     508
#
# /usr/local/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /usr/local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# /usr/local/lib/python3.8/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# /usr/local/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# /usr/local/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# /usr/local/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# /usr/local/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# /usr/local/lib/python3.8/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# /usr/local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# /usr/local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0xffff7f5a9f70>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-14-5bb946aaeb60> in <module>
# ----> 1 Vocabulary.init()
#
# /usr/local/lib/python3.8/site-packages/elasticsearch_dsl/document.py in init(cls, index, using)
#     154         if index:
#     155             i = i.clone(name=index)
# --> 156         i.save(using=using)
#     157
#     158     def _get_index(self, index=None, required=True):
#
# /usr/local/lib/python3.8/site-packages/elasticsearch_dsl/index.py in save(self, using)
#     296         fail with the underlying exception.
#     297         """
# --> 298         if not self.exists(using=using):
#     299             return self.create(using=using)
#     300
#
# /usr/local/lib/python3.8/site-packages/elasticsearch_dsl/index.py in exists(self, using, **kwargs)
#     412         ``Elasticsearch.indices.exists`` unchanged.
#     413         """
# --> 414         return self._get_connection(using).indices.exists(index=self._name, **kwargs)
#     415
#     416     def exists_type(self, using=None, **kwargs):
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     151                 if p in kwargs:
#     152                     params[p] = kwargs.pop(p)
# --> 153             return func(*args, params=params, headers=headers, **kwargs)
#     154
#     155         return _wrapped
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/client/indices.py in exists(self, index, params, headers)
#     330             raise ValueError("Empty value passed for a required argument 'index'.")
#     331
# --> 332         return self.transport.perform_request(
#     333             "HEAD", _make_path(index), params=params, headers=headers
#     334         )
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     411                     # raise exception on last retry
#     412                     if attempt == self.max_retries:
# --> 413                         raise e
#     414                 else:
#     415                     raise e
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     379
#     380             try:
# --> 381                 status, headers_response, data = connection.perform_request(
#     382                     method,
#     383                     url,
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     262             if isinstance(e, ReadTimeoutError):
#     263                 raise ConnectionTimeout("TIMEOUT", str(e), e)
# --> 264             raise ConnectionError("N/A", str(e), e)
#     265
#     266         # raise warnings if any from the 'Warnings' header.
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0xffff7f5a9f70>: Failed to establish a new connection: [Errno 111] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0xffff7f5a9f70>: Failed to establish a new connection: [Errno 111] Connection refused)

# %%
from elasticsearch_dsl import connections
connections.create_connection(
            hosts=["localhost:9200"], timeout=60
        )
# Out:
# <Elasticsearch([{'host': 'localhost', 'port': 9200}])>

# %%
from collections import Counter
import string


IGNORE_TOKENS = ['the', 'of', 'to', 'and', 'a', 'in', 'is', 'that', 'as', 'are', 'was', 'on', 'at', 'not', 'for', 'be', 'it', 'we', 'or', 'his', 'an', 'you', 'this', 'by', 'can', 'our', 'i', 'have', 'their', 'from', 'one', 'they', 'there', 'with', 'but', 'people', 'human', '\\xe2\\x80\\x95', 'had', 'my', 'what', 'do', 'more', 'your', 'many', 'he', 'its', 'all', 'could', 'online', 'use', 'has', '(', ')', 'also', 'who', 'most', 'than', 'if', 'some', 'when', 'new', 'does', 'should', 'will', 'about', 'where', 'being', 'way']

table = str.maketrans('', '', string.punctuation) 

word_counter = Counter()
with open('../seed/raw.txt', 'r') as f:
    for block in f:
        words = str(block).lower().translate(table).split(' ')
        words = [w for w in words if w not in IGNORE_TOKENS and not w.isdigit()]
        
        for word in words:
            word_counter[word] += 1
            
print(word_counter.most_common()[-50:])
# Out:
# [('me”', 1), ('ran', 1), ('away', 1), ('mom”', 1), ('excited', 1), ('pleased', 1), ('rid', 1), ('lesson', 1), ('till', 1), ('came', 1), ('back', 1), ('interfered', 1), ('business', 1), ('playful', 1), ('curious', 1), ('interested', 1), ('committed', 1), ('himself', 1), ('secretly', 1), ('looked', 1), ('inside', 1), ('brother’s', 1), ('shouted', 1), ('working', 1), ('“mom', 1), ('he’s', 1), ('video”', 1), ('naughtily', 1), ('smiling', 1), ('mad', 1), ('bothering', 1), ('posted', 1), ('school', 1), ('angry', 1), ('naughty', 1), ('asked', 1), ('loudly', 1), ('felix”', 1), ('felix’s', 1), ('next', 1), ('hear', 1), ('“i’m', 1), ('lecture', 1), ('class”', 1), ('argued', 1), ('accusation', 1), ('mischievously', 1), ('stuck', 1), ('tongue', 1), ('brother\n', 1)]

# %%
from dataclasses import dataclass
from typing import List, Optional

@dataclass
class VocabFeed:
    name: str
    meaning: Optional[str] = None
    frequency: Optional[int] = None

    @staticmethod
    def from_counter(c: Counter):
        return [VocabFeed(name=voca, frequency=freq) for (voca, freq) in c.items()]

# %%
VocabFeed.from_counter(word_counter)
# Out:
# 1),
#  VocabFeed(name='hazards', meaning=None, frequency=1),
#  VocabFeed(name='scientist', meaning=None, frequency=1),
#  VocabFeed(name='devised', meaning=None, frequency=1),
#  VocabFeed(name='nonetheless', meaning=None, frequency=1),
#  VocabFeed(name='oneself', meaning=None, frequency=1),
#  VocabFeed(name='remains', meaning=None, frequency=1),
#  VocabFeed(name='problematic', meaning=None, frequency=1),
#  VocabFeed(name='obvious', meaning=None, frequency=3),
#  VocabFeed(name='drawback', meaning=None, frequency=2),
#  VocabFeed(name='danger', meaning=None, frequency=1),
#  VocabFeed(name='exists', meaning=None, frequency=1),
#  VocabFeed(name='nothing', meaning=None, frequency=1),
#  VocabFeed(name='reduce', meaning=None, frequency=2),
#  VocabFeed(name='range', meaning=None, frequency=1),
#  VocabFeed(name='data', meaning=None, frequency=1),
#  VocabFeed(name='generate', meaning=None, frequency=1),
#  VocabFeed(name='anatomy', meaning=None, frequency=1),
#  VocabFeed(name='physiology', meaning=None, frequency=1),
#  VocabFeed(name='vary', meaning=None, frequency=2),
#  VocabFeed(name='significant', meaning=None, frequency=2),
#  VocabFeed(name='according', meaning=None, frequency=1),
#  VocabFeed(name='gender', meaning=None, frequency=1),
#  VocabFeed(name='age', meaning=None, frequency=1),
#  VocabFeed(name='lifestyle', meaning=None, frequency=1),
#  VocabFeed(name='factors', meaning=None, frequency=1),
#  VocabFeed(name='experimental', meaning=None, frequency=1),
#  VocabFeed(name='results', meaning=None, frequency=4),
#  VocabFeed(name='derived', meaning=None, frequency=1),
#  VocabFeed(name='single', meaning=None, frequency=1),
#  VocabFeed(name='subject', meaning=None, frequency=1),
#  VocabFeed(name='therefore', meaning=None, frequency=2),
#  VocabFeed(name='value', meaning=None, frequency=2),
#  VocabFeed(name='subject’s', meaning=None, frequency=1),
#  VocabFeed(name='responses', meaning=None, frequency=1),
#  VocabFeed(name='typical', meaning=None, frequency=5),
#  VocabFeed(name='atypical', meaning=None, frequency=1),
#  VocabFeed(name='response', meaning=None, frequency=2),
#  VocabFeed(name='group\n', meaning=None, frequency=1),
#  VocabFeed(name='model', meaning=None, frequency=1),
#  VocabFeed(name='sumerian', meaning=None, frequency=1),
#  VocabFeed(name='economy', meaning=None, frequency=2),
#  VocabFeed(name='temple', meaning=None, frequency=2),
#  VocabFeed(name='functioned', meaning=None, frequency=1),
#  VocabFeed(name='administrative', meaning=None, frequency=2),
#  VocabFeed(name='authority', meaning=None, frequency=1),
#  VocabFeed(name='governing', meaning=None, frequency=1),
#  VocabFeed(name='commodity', meaning=None, frequency=1),
#  VocabFeed(name='production', meaning=None, frequency=1),
#  VocabFeed(name='collection', meaning=None, frequency=1),
#  VocabFeed(name='redistribution', meaning=None, frequency=1),
#  VocabFeed(name='discovery', meaning=None, frequency=1),
#  VocabFeed(name='tablets', meaning=None, frequency=2),
#  VocabFeed(name='complexes', meaning=None, frequency=1),
#  VocabFeed(name='uruk', meaning=None, frequency=1),
#  VocabFeed(name='suggests', meaning=None, frequency=1),
#  VocabFeed(name='token', meaning=None, frequency=1),
#  VocabFeed(name='consequently', meaning=None, frequency=1),
#  VocabFeed(name='evolved', meaning=None, frequency=2),
#  VocabFeed(name='tool', meaning=None, frequency=1),
#  VocabFeed(name='centralized', meaning=None, frequency=1),
#  VocabFeed(name='governance', meaning=None, frequency=1),
#  VocabFeed(name='lack', meaning=None, frequency=1),
#  VocabFeed(name='archaeological', meaning=None, frequency=1),
#  VocabFeed(name='evidence', meaning=None, frequency=1),
#  VocabFeed(name='urukperiod', meaning=None, frequency=1),
#  VocabFeed(name='domestic', meaning=None, frequency=1),
#  VocabFeed(name='sites', meaning=None, frequency=1),
#  VocabFeed(name='individuals', meaning=None, frequency=3),
#  VocabFeed(name='used', meaning=None, frequency=2),
#  VocabFeed(name='system', meaning=None, frequency=1),
#  VocabFeed(name='', meaning=None, frequency=22),
#  VocabFeed(name='matter', meaning=None, frequency=2),
#  VocabFeed(name='widespread', meaning=None, frequency=1),
#  VocabFeed(name='literacy', meaning=None, frequency=2),
#  VocabFeed(name='beginnings', meaning=None, frequency=1),
#  VocabFeed(name='identifiable', meaning=None, frequency=1),
#  VocabFeed(name='symbols', meaning=None, frequency=1),
#  VocabFeed(name='pictograms', meaning=None, frequency=1),
#  VocabFeed(name='early', meaning=None, frequency=1),
#  VocabFeed(name='consistent', meaning=None, frequency=1),
#  VocabFeed(name='administrators', meaning=None, frequency=1),
#  VocabFeed(name='needing', meaning=None, frequency=1),
#  VocabFeed(name='lexicon', meaning=None, frequency=1),
#  VocabFeed(name='mutually', meaning=None, frequency=1),
#  VocabFeed(name='intelligible', meaning=None, frequency=1),
#  VocabFeed(name='literate', meaning=None, frequency=1),
#  VocabFeed(name='nonliterate', meaning=None, frequency=1),
#  VocabFeed(name='parties', meaning=None, frequency=2),
#  VocabFeed(name='cuneiform', meaning=None, frequency=1),
#  VocabFeed(name='script', meaning=None, frequency=1),
#  VocabFeed(name='abstract', meaning=None, frequency=1),
#  VocabFeed(name='increasingly', meaning=None, frequency=1),
#  VocabFeed(name='ensure', meaning=None, frequency=1),
#  VocabFeed(name='understood', meaning=None, frequency=1),
#  VocabFeed(name='she', meaning=None, frequency=1),
#  VocabFeed(name='agreed', meaning=None, frequency=1),
#  VocabFeed(name='to\n', meaning=None, frequency=1),
#  VocabFeed(name='bandwagon', meaning=None, frequency=1),
#  VocabFeed(name='effect', meaning=None, frequency=1),
#  VocabFeed(name='occurs', meaning=None, frequency=1),
#  VocabFeed(name='demonstrated', meaning=None, frequency=1),
#  VocabFeed(name='history', meaning=None, frequency=2),
#  VocabFeed(name='measurements', meaning=None, frequency=1),
#  VocabFeed(name='speed', meaning=None, frequency=3),
#  VocabFeed(name='light', meaning=None, frequency=1),
#  VocabFeed(name='because', meaning=None, frequency=4),
#  VocabFeed(name='basis', meaning=None, frequency=1),
#  VocabFeed(name='relativity', meaning=None, frequency=1),
#  VocabFeed(name='frequently', meaning=None, frequency=1),
#  VocabFeed(name='carefully', meaning=None, frequency=1),
#  VocabFeed(name='measured', meaning=None, frequency=2),
#  VocabFeed(name='quantities', meaning=None, frequency=1),
#  VocabFeed(name='science', meaning=None, frequency=3),
#  VocabFeed(name='far', meaning=None, frequency=1),
#  VocabFeed(name='hasn’t', meaning=None, frequency=1),
#  VocabFeed(name='however', meaning=None, frequency=5),
#  VocabFeed(name='found', meaning=None, frequency=3),
#  VocabFeed(name='speeds', meaning=None, frequency=2),
#  VocabFeed(name='too', meaning=None, frequency=4),
#  VocabFeed(name='opposite', meaning=None, frequency=1),
#  VocabFeed(name='happened', meaning=None, frequency=2),
#  VocabFeed(name='low', meaning=None, frequency=2),
#  VocabFeed(name='kind', meaning=None, frequency=1),
#  VocabFeed(name='error', meaning=None, frequency=1),
#  VocabFeed(name='side', meaning=None, frequency=2),
#  VocabFeed(name='real', meaning=None, frequency=2),
#  VocabFeed(name='called', meaning=None, frequency=1),
#  VocabFeed(name='“bias”', meaning=None, frequency=1),
#  VocabFeed(name='probably', meaning=None, frequency=2),
#  VocabFeed(name='adjusted', meaning=None, frequency=1),
#  VocabFeed(name='3match', meaning=None, frequency=1),
#  VocabFeed(name='expected', meaning=None, frequency=2),
#  VocabFeed(name='find', meaning=None, frequency=1),
#  VocabFeed(name='fit', meaning=None, frequency=2),
#  VocabFeed(name='kept', meaning=None, frequency=1),
#  VocabFeed(name='didn’t', meaning=None, frequency=1),
#  VocabFeed(name='threw', meaning=None, frequency=1),
#  VocabFeed(name='weren’t', meaning=None, frequency=1),
#  VocabFeed(name='intentionally', meaning=None, frequency=1),
#  VocabFeed(name='dishonest', meaning=None, frequency=1),
#  VocabFeed(name='influenced', meaning=None, frequency=1),
#  VocabFeed(name='conventional', meaning=None, frequency=1),
#  VocabFeed(name='wisdom', meaning=None, frequency=1),
#  VocabFeed(name='pattern', meaning=None, frequency=1),
#  VocabFeed(name='someone', meaning=None, frequency=2),
#  VocabFeed(name='lacked', meaning=None, frequency=1),
#  VocabFeed(name='courage', meaning=None, frequency=1),
#  VocabFeed(name='report', meaning=None, frequency=1),
#  VocabFeed(name='actually', meaning=None, frequency=2),
#  VocabFeed(name='expected\n', meaning=None, frequency=1),
#  VocabFeed(name='similar', meaning=None, frequency=8),
#  VocabFeed(name='rationale', meaning=None, frequency=1),
#  VocabFeed(name='assessing', meaning=None, frequency=1),
#  VocabFeed(name='survivability', meaning=None, frequency=1),
#  VocabFeed(name='risky', meaning=None, frequency=1),
#  VocabFeed(name='turns', meaning=None, frequency=2),
#  VocabFeed(name='deadly', meaning=None, frequency=1),
#  VocabFeed(name='instance', meaning=None, frequency=4),
#  VocabFeed(name='might', meaning=None, frequency=2),
#  VocabFeed(name='late', meaning=None, frequency=1),
#  VocabFeed(name='desire', meaning=None, frequency=1),
#  VocabFeed(name='associate', meaning=None, frequency=1),
#  VocabFeed(name='perform', meaning=None, frequency=1),
#  VocabFeed(name='function', meaning=None, frequency=1),
#  VocabFeed(name='efficiently', meaning=None, frequency=2),
#  VocabFeed(name='especially', meaning=None, frequency=1),
#  VocabFeed(name='useful', meaning=None, frequency=1),
#  VocabFeed(name='species', meaning=None, frequency=2),
#  VocabFeed(name='different', meaning=None, frequency=2),
#  VocabFeed(name='sorts', meaning=None, frequency=2),
#  VocabFeed(name='environments', meaning=None, frequency=1),
#  VocabFeed(name='carrying', meaning=None, frequency=1),
#  VocabFeed(name='capacity', meaning=None, frequency=1),
#  VocabFeed(name='resources', meaning=None, frequency=1),
#  VocabFeed(name='very', meaning=None, frequency=6),
#  VocabFeed(name='live', meaning=None, frequency=3),
#  VocabFeed(name='cannot', meaning=None, frequency=3),
#  VocabFeed(name='exact', meaning=None, frequency=1),
#  VocabFeed(name='same', meaning=None, frequency=2),
#  VocabFeed(name='thing', meaning=None, frequency=1),
#  VocabFeed(name='example', meaning=None, frequency=2),
#  VocabFeed(name='few', meaning=None, frequency=2),
#  VocabFeed(name='trees', meaning=None, frequency=1),
#  VocabFeed(name='tree', meaning=None, frequency=1),
#  VocabFeed(name='houses', meaning=None, frequency=1),
#  VocabFeed(name='mangoes', meaning=None, frequency=2),
#  VocabFeed(name='short', meaning=None, frequency=1),
#  VocabFeed(name='supply', meaning=None, frequency=1),
#  VocabFeed(name='solely', meaning=None, frequency=1),
#  VocabFeed(name='diet', meaning=None, frequency=1),
#  VocabFeed(name='rational', meaning=None, frequency=1),
#  VocabFeed(name='strategy', meaning=None, frequency=1),
#  VocabFeed(name='sometimes', meaning=None, frequency=2),
#  VocabFeed(name='members', meaning=None, frequency=5),
#  VocabFeed(name='one’s', meaning=None, frequency=1),
#  VocabFeed(name='species\n', meaning=None, frequency=1),
#  VocabFeed(name='thanks', meaning=None, frequency=1),
#  VocabFeed(name='newly', meaning=None, frequency=1),
#  VocabFeed(name='neuroimaging', meaning=None, frequency=1),
#  VocabFeed(name='technology', meaning=None, frequency=7),
#  VocabFeed(name='brain', meaning=None, frequency=3),
#  VocabFeed(name='changes', meaning=None, frequency=2),
#  VocabFeed(name='occur', meaning=None, frequency=1),
#  VocabFeed(name='though', meaning=None, frequency=1),
#  VocabFeed(name='brains', meaning=None, frequency=2),
#  VocabFeed(name='contain', meaning=None, frequency=2),
#  VocabFeed(name='basic', meaning=None, frequency=1),
#  VocabFeed(name='structures', meaning=None, frequency=1),
#  VocabFeed(name='neural', meaning=None, frequency=2),
#  VocabFeed(name='fingerprints', meaning=None, frequency=1),
#  VocabFeed(name='latest', meaning=None, frequency=1),
#  VocabFeed(name='developmental', meaning=None, frequency=1),
#  VocabFeed(name='neuroscience', meaning=None, frequency=1),
#  VocabFeed(name='research', meaning=None, frequency=1),
#  VocabFeed(name='malleable', meaning=None, frequency=1),
#  VocabFeed(name='throughout', meaning=None, frequency=1),
#  VocabFeed(name='previously', meaning=None, frequency=1),
#  VocabFeed(name='assumed', meaning=None, frequency=1),
#  VocabFeed(name='develops', meaning=None, frequency=2),
#  VocabFeed(name='processes', meaning=None, frequency=1),
#  VocabFeed(name='immediate', meaning=None, frequency=1),
#  VocabFeed(name='distant', meaning=None, frequency=1),
#  VocabFeed(name='“environments”', meaning=None, frequency=1),
#  VocabFeed(name='past', meaning=None, frequency=1),
#  VocabFeed(name='current', meaning=None, frequency=1),
#  VocabFeed(name='situations', meaning=None, frequency=1),
#  VocabFeed(name='seeks', meaning=None, frequency=1),
#  VocabFeed(name='meaning', meaning=None, frequency=1),
#  VocabFeed(name='establishing', meaning=None, frequency=1),
#  VocabFeed(name='refining', meaning=None, frequency=1),
#  VocabFeed(name='existing', meaning=None, frequency=1),
#  VocabFeed(name='learn', meaning=None, frequency=1),
#  VocabFeed(name='fact', meaning=None, frequency=2),
#  VocabFeed(name='skill', meaning=None, frequency=2),
#  VocabFeed(name='neurons', meaning=None, frequency=1),
#  VocabFeed(name='communicate', meaning=None, frequency=1),
#  VocabFeed(name='form', meaning=None, frequency=2),
#  VocabFeed(name='connected', meaning=None, frequency=1),
#  VocabFeed(name='information', meaning=None, frequency=1),
#  VocabFeed(name='using', meaning=None, frequency=3),
#  VocabFeed(name='knowledge', meaning=None, frequency=1),
#  VocabFeed(name='structural', meaning=None, frequency=1),
#  VocabFeed(name='allow', meaning=None, frequency=1),
#  VocabFeed(name='future', meaning=None, frequency=1),
#  VocabFeed(name='impulses', meaning=None, frequency=1),
#  VocabFeed(name='travel', meaning=None, frequency=1),
#  VocabFeed(name='highactivity', meaning=None, frequency=1),
#  VocabFeed(name='synaptic', meaning=None, frequency=1),
#  VocabFeed(name='connections', meaning=None, frequency=2),
#  VocabFeed(name='stabilized', meaning=None, frequency=1),
#  VocabFeed(name='strengthened', meaning=None, frequency=1),
#  VocabFeed(name='while', meaning=None, frequency=5),
#  VocabFeed(name='relatively', meaning=None, frequency=1),
#  VocabFeed(name='weakened', meaning=None, frequency=1),
#  VocabFeed(name='eventually', meaning=None, frequency=1),
#  VocabFeed(name='pruned', meaning=None, frequency=1),
#  VocabFeed(name='are\n', meaning=None, frequency=1),
#  VocabFeed(name='workers', meaning=None, frequency=2),
#  VocabFeed(name='united', meaning=None, frequency=1),
#  VocabFeed(name='laughing', meaning=None, frequency=1),
#  VocabFeed(name='shared', meaning=None, frequency=3),
#  VocabFeed(name='events', meaning=None, frequency=3),
#  VocabFeed(name='initially', meaning=None, frequency=1),
#  VocabFeed(name='spark', meaning=None, frequency=1),
#  VocabFeed(name='anger', meaning=None, frequency=1),
#  VocabFeed(name='conflict', meaning=None, frequency=1),
#  VocabFeed(name='humor', meaning=None, frequency=5),
#  VocabFeed(name='reframes', meaning=None, frequency=1),
#  VocabFeed(name='potentially', meaning=None, frequency=1),
#  VocabFeed(name='divisive', meaning=None, frequency=1),
#  VocabFeed(name='into', meaning=None, frequency=2),
#  VocabFeed(name='merely', meaning=None, frequency=1),
#  VocabFeed(name='“laughable”', meaning=None, frequency=1),
#  VocabFeed(name='perspective', meaning=None, frequency=3),
#  VocabFeed(name='subservient', meaning=None, frequency=1),
#  VocabFeed(name='unifying', meaning=None, frequency=1),
#  VocabFeed(name='values', meaning=None, frequency=2),
#  VocabFeed(name='held', meaning=None, frequency=1),
#  VocabFeed(name='repeatedly', meaning=None, frequency=1),
#  VocabFeed(name='recounting', meaning=None, frequency=1),
#  VocabFeed(name='humorous', meaning=None, frequency=2),
#  VocabFeed(name='incidents', meaning=None, frequency=1),
#  VocabFeed(name='reinforces', meaning=None, frequency=1),
#  VocabFeed(name='unity', meaning=None, frequency=1),
#  VocabFeed(name='based', meaning=None, frequency=1),
#  VocabFeed(name='key', meaning=None, frequency=1),
#  VocabFeed(name='organizational', meaning=None, frequency=1),
#  VocabFeed(name='1one', meaning=None, frequency=1),
#  VocabFeed(name='team', meaning=None, frequency=1),
#  VocabFeed(name='told', meaning=None, frequency=1),
#  VocabFeed(name='stories', meaning=None, frequency=2),
#  VocabFeed(name='dumpster', meaning=None, frequency=1),
#  VocabFeed(name='fire', meaning=None, frequency=1),
#  VocabFeed(name='seem', meaning=None, frequency=1),
#  VocabFeed(name='funny', meaning=None, frequency=3),
#  VocabFeed(name='reactions', meaning=None, frequency=1),
#  VocabFeed(name='motivated', meaning=None, frequency=1),
#  VocabFeed(name='preserve', meaning=None, frequency=1),
#  VocabFeed(name='safety', meaning=None, frequency=1),
#  VocabFeed(name='sparked', meaning=None, frequency=1),
#  VocabFeed(name='laughter', meaning=None, frequency=2),
#  VocabFeed(name='multiple', meaning=None, frequency=2),
#  VocabFeed(name='workplace', meaning=None, frequency=1),
#  VocabFeed(name='cause', meaning=None, frequency=1),
#  VocabFeed(name='indicate', meaning=None, frequency=2),
#  VocabFeed(name='sense', meaning=None, frequency=5),
#  VocabFeed(name='belonging', meaning=None, frequency=1),
#  VocabFeed(name='since', meaning=None, frequency=4),
#  VocabFeed(name='“you', meaning=None, frequency=1),
#  VocabFeed(name='there”', meaning=None, frequency=1),
#  VocabFeed(name='nonmembers', meaning=None, frequency=1),
#  VocabFeed(name='capture', meaning=None, frequency=1),
#  VocabFeed(name='people’s', meaning=None, frequency=1),
#  VocabFeed(name='attention', meaning=None, frequency=1),
#  VocabFeed(name='commercials', meaning=None, frequency=1),
#  VocabFeed(name='tend', meaning=None, frequency=1),
#  VocabFeed(name='elements', meaning=None, frequency=1),
#  VocabFeed(name='faces', meaning=None, frequency=1),
#  VocabFeed(name='gestures', meaning=None, frequency=1),
#  VocabFeed(name='instances', meaning=None, frequency=1),
#  VocabFeed(name='serve', meaning=None, frequency=1),
#  VocabFeed(name='enact', meaning=None, frequency=1),
#  VocabFeed(name='bonds', meaning=None, frequency=1),
#  VocabFeed(name='understanding', meaning=None, frequency=1),
#  VocabFeed(name='informal', meaning=None, frequency=1),
#  VocabFeed(name='badge', meaning=None, frequency=1),
#  VocabFeed(name='membership', meaning=None, frequency=1),
#  VocabFeed(name='organization\n', meaning=None, frequency=1),
#  VocabFeed(name='successful', meaning=None, frequency=1),
#  VocabFeed(name='integration', meaning=None, frequency=1),
#  VocabFeed(name='educational', meaning=None, frequency=2),
#  VocabFeed(name='marked', meaning=None, frequency=1),
#  VocabFeed(name='regarded', meaning=None, frequency=2),
#  VocabFeed(name='users', meaning=None, frequency=3),
#  VocabFeed(name='unobtrusive', meaning=None, frequency=1),
#  VocabFeed(name='facilitator', meaning=None, frequency=1),
#  VocabFeed(name='instruction', meaning=None, frequency=2),
#  VocabFeed(name='performance', meaning=None, frequency=2),
#  VocabFeed(name='shifts', meaning=None, frequency=1),
#  VocabFeed(name='purpose', meaning=None, frequency=4),
#  VocabFeed(name='serves', meaning=None, frequency=1),
#  VocabFeed(name='becoming', meaning=None, frequency=1),
#  VocabFeed(name='comfortable', meaning=None, frequency=1),
#  VocabFeed(name='trusted', meaning=None, frequency=1),
#  VocabFeed(name='element', meaning=None, frequency=1),
#  VocabFeed(name='successfully', meaning=None, frequency=2),
#  VocabFeed(name='integrated', meaning=None, frequency=2),
#  VocabFeed(name='thought', meaning=None, frequency=1),
#  VocabFeed(name='ballpoint', meaning=None, frequency=1),
#  VocabFeed(name='pen', meaning=None, frequency=1),
#  VocabFeed(name='although', meaning=None, frequency=1),
#  VocabFeed(name='mechanisms', meaning=None, frequency=2),
#  VocabFeed(name='twist', meaning=None, frequency=1),
#  VocabFeed(name='mechanism', meaning=None, frequency=2),
#  VocabFeed(name='push', meaning=None, frequency=1),
#  VocabFeed(name='top', meaning=None, frequency=1),
#  VocabFeed(name='variations', meaning=None, frequency=1),
#  VocabFeed(name='personal', meaning=None, frequency=2),
#  VocabFeed(name='computers', meaning=None, frequency=1),
#  VocabFeed(name='reached', meaning=None, frequency=1),
#  ...]

# %%
word_counter.items()
# Out:
# lion’s', 1), ('historians’', 1), ('put', 3), ('across', 1), ('point', 5), ('view', 2), ('environment', 5), ('make', 3), ('laws', 1), ('voice', 2), ('wild', 1), ('india', 1), ('present', 1), ('rate', 1), ('consumption', 2), ('completely', 1), ('unsustainable', 1), ('forest', 1), ('wetlands', 1), ('wastelands', 1), ('coastal', 1), ('zones', 2), ('ecosensitive', 1), ('seen', 2), ('disposable', 1), ('accelerating', 1), ('demands', 1), ('population', 2), ('ask', 3), ('any', 3), ('change', 2), ('behaviour', 1), ('―', 12), ('whether', 2), ('cut', 1), ('alter', 1), ('lifestyles', 1), ('decrease', 1), ('growth', 1), ('violation', 1), ('rights', 4), ('‘wrongs’', 1), ('changed', 3), ('thinking', 1), ('difference', 1), ('between', 4), ('humans', 3), ('rest', 3), ('environment\n', 1), ('difficulties', 1), ('arise', 1), ('think', 3), ('machines', 4), ('collaborative', 1), ('systems', 2), ('assign', 1), ('whatever', 2), ('tasks', 1), ('automated', 1), ('leave', 1), ('ends', 1), ('up', 6), ('requiring', 1), ('behave', 1), ('machinelike', 1), ('fashion', 1), ('ways', 4), ('differ', 1), ('capabilities', 2), ('expect', 1), ('monitor', 1), ('which', 7), ('means', 3), ('keeping', 1), ('alert', 1), ('long', 3), ('periods', 1), ('something', 3), ('bad', 5), ('require', 1), ('repeated', 2), ('operations', 1), ('extreme', 1), ('precision', 1), ('accuracy', 1), ('required', 2), ('divide', 1), ('machine', 1), ('components', 1), ('task', 1), ('fail', 2), ('take', 3), ('advantage', 1), ('strengths', 1), ('rely', 1), ('upon', 1), ('genetically', 1), ('biologically', 1), ('unsuited', 1), ('yet', 1), ('blamed\n', 1), ('prior', 1), ('filesharing', 1), ('services', 2), ('music', 8), ('albums', 1), ('landed', 1), ('exclusively', 1), ('critics', 5), ('before', 3), ('release', 1), ('these', 3), ('would', 5), ('listen', 1), ('them', 5), ('well', 2), ('general', 1), ('public', 4), ('preview', 1), ('world', 2), ('reviews', 4), ('internet', 1), ('made', 3), ('easily', 2), ('accessible', 1), ('allowed', 1), ('advanced', 1), ('releases', 1), ('spread', 1), ('through', 3), ('social', 4), ('networks', 4), ('availability', 1), ('democratized', 1), ('meant', 1), ('longer', 1), ('unique', 2), ('access', 3), ('laypeople', 1), ('alike', 1), ('obtain', 1), ('simultaneously', 1), ('media', 2), ('enabled', 1), ('publicize', 1), ('views', 1), ('songs', 1), ('list', 1), ('bands', 1), ('bios', 1), ('argue', 1), ('endlessly', 1), ('message', 1), ('boards', 1), ('result', 3), ('opinions', 1), ('masses', 1), ('particular', 3), ('album', 1), ('writing', 2), ('thus', 1), ('guiding', 1), ('popular', 1), ('opinion', 1), ('toward', 2), ('art', 1), ('did', 1), ('preinternet', 1), ('times', 2), ('began', 1), ('reflect', 1), ('consciously', 1), ('subconsciously', 2), ('opinion\n', 1), ('don’t', 2), ('usually', 1), ('touch', 4), ('temporal', 1), ('phenomenon', 1), ('every', 1), ('bit', 1), ('timebased', 1), ('spatial', 1), ('experiment', 3), ('see', 3), ('yourself', 1), ('cup', 1), ('hand', 2), ('palm', 2), ('close', 1), ('eyes', 2), ('place', 2), ('small', 2), ('ordinary', 1), ('object', 2), ('ring', 1), ('eraser', 1), ('anything', 1), ('him', 4), ('identify', 2), ('without', 2), ('moving', 1), ('part', 1), ('clue', 1), ('weight', 1), ('maybe', 1), ('overall', 1), ('size', 2), ('then', 10), ('tell', 2), ('keep', 1), ('closed', 1), ('move', 2), ('fingers', 2), ('he’ll', 1), ('likely', 2), ('allowing', 1), ('you’ve', 1), ('added', 2), ('sensory', 1), ('perception', 1), ('there’s', 1), ('direct', 2), ('analogy', 1), ('fovea', 1), ('center', 1), ('retina', 1), ('fingertips', 1), ('both', 5), ('high', 5), ('acuity', 1), ('ability', 1), ('complex', 6), ('buttoning', 1), ('shirt', 1), ('unlocking', 1), ('front', 1), ('door', 2), ('dark', 1), ('depends', 1), ('continuous', 1), ('timevarying', 1), ('patterns', 1), ('sensation\n', 1), ('graph', 1), ('above', 1), ('shows', 1), ('shares', 1), ('retail', 8), ('sales', 8), ('each', 3), ('six', 2), ('countries', 2), ('share', 6), ('refers', 1), ('percentage ...
